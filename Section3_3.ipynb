# %% [markdown]
# # PART3 グラフを描いてみよう

# %% [markdown]
# ## おまじない

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## データの読み込み
# - train.csvを読み込みましょう
# - 読み込んだものは変数trainに代入しましょう

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# ## trainの先頭行を確かめてみましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## trainのyの折れ線グラフを描いてみましょう
# - 折れ線グラフを描くにはplot関数を使います

# %%
train['y'].plot()

# %% [markdown]
# ## グラフの大きさをもっと大きくしてみましょう
# - カッコの中にオプションとしてfigsize=(12,4)と書きます

# %%
train['y'].plot(figsize=(12, 4))

# %% [markdown]
# ## グラフにタイトルをつけてみましょう
# - カッコの中にオプションとして、title="XXX"と書きます
# - カッコの中が複数となった場合はカンマ（,）を使うことで複数書くことができます

# %%
train['y'].plot(figsize=(12, 4), title='graph')

# %% [markdown]
# ## グラフのx軸とy軸に名前を付けてみましょう
# - ちょっと複雑で一旦、plot関数の結果を別の変数に代入する必要があります
# - 今回は変数axに代入することにします
# - x軸はaxを使い、set_xlabel("name")と書くことで名前をつけることができます

# %%
ax = train['y'].plot(figsize=(12, 4), title='graph')
ax.set_xlabel('time')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## trainのyのヒストグラムを描いてみましょう
# - グラフを描く前に簡単にヒストグラムとは何かを理解しましょう
# - plot.hist関数を使います

# %%
train['y'].plot.hist()

# %% [markdown]
# ## グリッド線を引いてみましょう
# - カッコの中にオプションとして、grid=Trueと書きます

# %%
train['y'].plot.hist(grid=True)

# %% [markdown]
# ## ヒストグラム上に平均値を表す赤線を描きましょう
# - ヒストグラムで一番数が多いところが平均値とは限らないケースもある為、ヒストグラムに平均値を表す線を描いてみましょう
# - まず縦線の描き方から始めます。縦線を描くときにはplt.axvline(x=NUMBER, color="red")と書きます
# - vlineのvはvertical（垂直）

# %%
plt.axvline(x=2, color='red')

# %%
plt.axvline(x=train['y'].mean(), color='red')
train['y'].plot.hist()

# %% [markdown]
# ## 上記のヒストグラムを大きさ(12,4)にし、タイトルを"ヒストグラム"として、pngファイルの図として保存しましょう
# - plt.savefig("FILE_NAME.拡張子")を一番最後に書きます
# - ファイル名は「sample_fig.png」としましょう

# %%
plt.axvline(x=train['y'].mean(), color='red')
train['y'].plot.hist(figsize=(12, 4), title='histgram')
plt.savefig('sample_fig.png')

# %% [markdown]
# ## yとweekの関係を調べる為に、箱ひげ図を描いてみましょう
# - 箱ひげ図を描く前に簡単に箱ひげ図とは何かを理解しましょう
# - 箱ひげ図の描き方は、yとweekを選択した上で、boxplot(by="week")と書きます
# - by="week"はx軸にしたいカラムを選択します
# - ○は外れ値です

# %%
train[['y', 'week']].boxplot(by='week')
# Out:
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26376 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26408 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 27700 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 28779 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 37329 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %% [markdown]
# # 実習

# %% [markdown]
# 1.trainのtemperatureの折れ線グラフを描いてみよう。タイトルとx軸、y軸にもそれぞれ名前をつけよう
# - x軸とy軸に名前を付ける為に、グラフは一旦変数axに代入しよう
# - タイトル名は「気温」、x軸は「time」、y軸は「temperature」としよう

# %%
ax = train['temperature'].plot(title='temperature')
ax.set_xlabel('time')
ax.set_ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %% [markdown]
# 2.trainのkcalのヒストグラムを描いてみよう。trainのkcalの平均を表す赤線も入れよう

# %%
plt.axvline(x=train['kcal'].mean(), color='red')
train['kcal'].plot.hist()

# %% [markdown]
# 3.trainのyとweatherとの関係を調べる為に、箱ひげ図を描いてみよう
# - x軸はweatherにしましょう

# %%
train[['y', 'weather']].boxplot(by='weather')
# Out:
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26311 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 38632 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 38634 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/HashTak/Documents/Python/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0, flags=flags)
